# %%
import dataclasses


@dataclasses.dataclass
class User:
    __slots__ = ["uid", "alias"]
    uid: int
    alias: str

# %%
u = User(501, "anna")

# %%
u
# Out:
# User(uid=501, alias='anna')

# %%
dc = dataclasses

# %%
dc.asdict(u)
# Out:
# {'uid': 501, 'alias': 'anna'}
